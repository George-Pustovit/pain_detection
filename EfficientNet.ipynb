# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.applications import EfficientNetB0


# Установка параметров
img_size = 128  # Размеры изображений (например, 128x128 пикселей)
batch_size = 32 # Размер батча для обучения

# Генератор данных с масштабированием значений
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)

# Генерация данных для обучения
train_generator = datagen.flow_from_directory(
    'dataset',  # Путь к папке с данными
    target_size=(img_size, img_size),  # Размеры изображений
    batch_size=batch_size,
    class_mode='binary',  # Бинарная классификация (pain/no_pain)
    subset='training',  # Использовать для обучения
    shuffle=True
)

# Генерация данных для валидации
validation_generator = datagen.flow_from_directory(
    'dataset',  # Путь к папке с данными
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='binary',  # Бинарная классификация
    subset='validation'  # Использовать для валидации
)


# Загрузка модели EfficientNetB0
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))

# Создание модели
model = Sequential()
model.add(base_model)
base_model.trainable = False
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Компиляция и обучение
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(train_generator, steps_per_epoch=train_generator.samples // batch_size, epochs=50,
          validation_data=validation_generator, validation_steps=validation_generator.samples // batch_size)
# Out:
# Found 928 images belonging to 2 classes.
# Found 396 images belonging to 2 classes.
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001AC68541438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001AC68541438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 29/29 [==============================] - ETA: 0s - loss: 1.2024 - accuracy: 0.4989WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001AC6AE820D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001AC6AE820D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 29/29 [==============================] - 9s 207ms/step - loss: 1.2024 - accuracy: 0.4989 - val_loss: 0.7604 - val_accuracy: 0.5000
# Epoch 2/50
# 29/29 [==============================] - 1s 38ms/step - loss: 0.7475 - accuracy: 0.4968 - val_loss: 0.6938 - val_accuracy: 0.5078
# Epoch 3/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7206 - accuracy: 0.4634 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 4/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7049 - accuracy: 0.5011 - val_loss: 0.6950 - val_accuracy: 0.5078
# Epoch 5/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7010 - accuracy: 0.5226 - val_loss: 0.7117 - val_accuracy: 0.5026
# Epoch 6/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7097 - accuracy: 0.5097 - val_loss: 0.7953 - val_accuracy: 0.5000
# Epoch 7/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7528 - accuracy: 0.4569 - val_loss: 0.6992 - val_accuracy: 0.5026
# Epoch 8/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.7109 - accuracy: 0.5194 - val_loss: 0.7111 - val_accuracy: 0.5000
# Epoch 9/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7177 - accuracy: 0.4978 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 10/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7378 - accuracy: 0.5097 - val_loss: 0.7053 - val_accuracy: 0.5104
# Epoch 11/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.7596 - accuracy: 0.5075 - val_loss: 0.7014 - val_accuracy: 0.5052
# Epoch 12/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.7374 - accuracy: 0.5086 - val_loss: 0.7655 - val_accuracy: 0.4948
# Epoch 13/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.7098 - accuracy: 0.4946 - val_loss: 0.6936 - val_accuracy: 0.5026
# Epoch 14/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.7101 - accuracy: 0.4774 - val_loss: 0.7252 - val_accuracy: 0.5000
# Epoch 15/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7195 - accuracy: 0.5194 - val_loss: 0.7370 - val_accuracy: 0.5000
# Epoch 16/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.7063 - accuracy: 0.4871 - val_loss: 0.6987 - val_accuracy: 0.5026
# Epoch 17/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.7214 - accuracy: 0.4989 - val_loss: 0.8713 - val_accuracy: 0.4974
# Epoch 18/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.7197 - accuracy: 0.5291 - val_loss: 0.7093 - val_accuracy: 0.5026
# Epoch 19/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7136 - accuracy: 0.5011 - val_loss: 0.6931 - val_accuracy: 0.5026
# Epoch 20/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.8061 - accuracy: 0.4569 - val_loss: 0.7086 - val_accuracy: 0.5000
# Epoch 21/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7379 - accuracy: 0.4925 - val_loss: 0.7149 - val_accuracy: 0.5026
# Epoch 22/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.7380 - accuracy: 0.5043 - val_loss: 0.6930 - val_accuracy: 0.4974
# Epoch 23/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.7169 - accuracy: 0.4914 - val_loss: 0.7122 - val_accuracy: 0.4974
# Epoch 24/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.7279 - accuracy: 0.5000 - val_loss: 0.7043 - val_accuracy: 0.4948
# Epoch 25/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.7363 - accuracy: 0.5140 - val_loss: 0.7199 - val_accuracy: 0.5000
# Epoch 26/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.7545 - accuracy: 0.5075 - val_loss: 0.6936 - val_accuracy: 0.5078
# Epoch 27/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.7483 - accuracy: 0.5205 - val_loss: 0.6961 - val_accuracy: 0.5000
# Epoch 28/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7130 - accuracy: 0.4817 - val_loss: 0.6938 - val_accuracy: 0.5026
# Epoch 29/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7345 - accuracy: 0.5054 - val_loss: 0.7077 - val_accuracy: 0.5000
# Epoch 30/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.7394 - accuracy: 0.4925 - val_loss: 0.6972 - val_accuracy: 0.4948
# Epoch 31/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7244 - accuracy: 0.4806 - val_loss: 0.7156 - val_accuracy: 0.4974
# Epoch 32/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7285 - accuracy: 0.4795 - val_loss: 0.7021 - val_accuracy: 0.5000
# Epoch 33/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.7324 - accuracy: 0.5129 - val_loss: 0.6932 - val_accuracy: 0.4974
# Epoch 34/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.7528 - accuracy: 0.4968 - val_loss: 0.7838 - val_accuracy: 0.5000
# Epoch 35/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7355 - accuracy: 0.5054 - val_loss: 0.8171 - val_accuracy: 0.5000
# Epoch 36/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7778 - accuracy: 0.4892 - val_loss: 0.6973 - val_accuracy: 0.5000
# Epoch 37/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7084 - accuracy: 0.4860 - val_loss: 0.7003 - val_accuracy: 0.4974
# Epoch 38/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7014 - accuracy: 0.5248 - val_loss: 0.6939 - val_accuracy: 0.5052
# Epoch 39/50
# 29/29 [==============================] - 1s 34ms/step - loss: 0.7298 - accuracy: 0.5043 - val_loss: 0.6979 - val_accuracy: 0.5000
# Epoch 40/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.7452 - accuracy: 0.5097 - val_loss: 0.8313 - val_accuracy: 0.4974
# Epoch 41/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7229 - accuracy: 0.4914 - val_loss: 0.6976 - val_accuracy: 0.5026
# Epoch 42/50
# 29/29 [==============================] - 1s 35ms/step - loss: 0.7113 - accuracy: 0.4903 - val_loss: 0.7474 - val_accuracy: 0.4974
# Epoch 43/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.7117 - accuracy: 0.5280 - val_loss: 0.6932 - val_accuracy: 0.4974
# Epoch 44/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7182 - accuracy: 0.4666 - val_loss: 0.6985 - val_accuracy: 0.4948
# Epoch 45/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7705 - accuracy: 0.5054 - val_loss: 0.7827 - val_accuracy: 0.4974
# Epoch 46/50
# 29/29 [==============================] - 1s 33ms/step - loss: 0.7232 - accuracy: 0.4935 - val_loss: 0.7217 - val_accuracy: 0.4948
# Epoch 47/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7116 - accuracy: 0.5032 - val_loss: 0.7003 - val_accuracy: 0.4948
# Epoch 48/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7024 - accuracy: 0.5119 - val_loss: 0.7818 - val_accuracy: 0.5052
# Epoch 49/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7225 - accuracy: 0.4709 - val_loss: 0.7166 - val_accuracy: 0.5000
# Epoch 50/50
# 29/29 [==============================] - 1s 32ms/step - loss: 0.7045 - accuracy: 0.5216 - val_loss: 0.6946 - val_accuracy: 0.5052
